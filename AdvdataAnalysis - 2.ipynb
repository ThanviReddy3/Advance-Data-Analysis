# %% [markdown]
# Analysis - 2

# %%
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import re
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\india\My Python Files\DataAnalysisProject\Cleanedautos.csv')
df = df.drop(columns = ['Unnamed: 0'])

# %% [markdown]
#  1. Can you tell me No of Vehicles by Brand Available on ebay for sale with the help of visualization

# %%
df['brand'].value_counts().plot(kind = 'bar', color = 'brown')
# Out:
# <Axes: xlabel='brand'>

# %% [markdown]
# * volkswagen brand has highest number of sales on ebay

# %% [markdown]
# 2. What is the Average price for vehicles based on the type of vehicle as well as on the type of gearbox.Explain me with both numerical and visualization analysis

# %%
pd.crosstab(index = df['vehicleType'], columns = df['gearbox'], values = df['price'], aggfunc = 'mean')
# Out:
# gearbox         automatic        manual
# vehicleType
# andere        8983.550926   4291.836538
# bus          11111.818360   6187.203371
# cabrio       16148.505927   8977.921948
# coupe        16402.412235  10436.160581
# kleinwagen    4276.086465   3161.149184
# kombi         9299.356506   5174.277380
# limousine    10182.468528   4965.362099
# suv          17278.553939  10456.736365

# %%
pd.crosstab(index =df['vehicleType'],columns =df["gearbox"], values = df['price'],aggfunc='mean' )
# Out:
# gearbox         automatic        manual
# vehicleType
# andere        8983.550926   4291.836538
# bus          11111.818360   6187.203371
# cabrio       16148.505927   8977.921948
# coupe        16402.412235  10436.160581
# kleinwagen    4276.086465   3161.149184
# kombi         9299.356506   5174.277380
# limousine    10182.468528   4965.362099
# suv          17278.553939  10456.736365

# %%
pd.crosstab(index =df['vehicleType'],columns =df["gearbox"], values = df['price'],aggfunc='mean' ).plot(kind = 'bar')
# Out:
# <Axes: xlabel='vehicleType'>

# %% [markdown]
# * Above graph shows Average price of vehicles based on the geartype and SUV has highest price in automatic gearbox, price of cabrio and coupe has almost equal price on automatic geartype.

# %% [markdown]
# 3. What is the marginal probability of private seller

# %%
df['seller'].value_counts()/len(df)
# Out:
# seller
# private       0.999993
# gewerblich    0.000007
# Name: count, dtype: float64

# %%
df["seller"].value_counts()[0]/len(df)
# Out:
# C:\Users\india\AppData\Local\Temp\ipykernel_10760\662477129.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df["seller"].value_counts()[0]/len(df)
# 0.9999928713238309
